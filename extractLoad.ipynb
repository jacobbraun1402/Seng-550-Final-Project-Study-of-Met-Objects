# %%
from pyspark.sql import SparkSession
#used to read from Met's object API
import requests
import time
from IPython.display import clear_output

# %%
spark = SparkSession.builder.master("local[4]").appName("Extract").config("spark.ui.port", '4050').getOrCreate()
sc = spark.sparkContext
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/12/19 19:47:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# get the IDs of all of the objects in the collection
ids = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/objects').json()

# %%
# put IDs in list
ids_rdd = sc.parallelize(ids["objectIDs"])

# %%
# select random sample of objects in the database
# n represents the approximate total number of records to collect
n = 10000
ids_sample = ids_rdd.sample(withReplacement=False, fraction=(n/ids["total"]), seed=1)

# %%
id_list = list(ids_sample.collect())

# %%
# The API requires that requests/second is limited to 80
# quick and dirty solution: make request, then sleep for 1/80 seconds
# build a list of JSON objects
# pick objects based on the IDs that were randomly selected above
# This process is extremely slow so I can't get more than 10,000 records in a reasonable amount of time
# Collecting 9974 objects took 39 minutes
url = 'https://collectionapi.metmuseum.org/public/collection/v1/objects/'
objects = []
i = 0
id_total = len(id_list)
for id in id_list:
    i += 1
    clear_output(wait=True)
    path = url+str(id)
    print("Collecting object {a}/{b}\nObject ID: {c}".format(a=i, b=id_total, c=id))
    request = requests.get(path)
    obj_dict = request.json()
    if "message" in obj_dict:
        print(obj_dict)
        break
    else:
        objects.append(obj_dict)
    time.sleep(float(1/80))
# Out:
# Collecting object 9974/9974
# Object ID: 832623

# %%
def getFields(obj:dict):
    # The fields I want to keep
    keys = ['objectID', 'isHighlight', 'accessionYear', 'department', 'objectName', 
            'culture','artistNationality', 'artistGender', 'objectEndDate', 'isTimelineWork']
    new_obj = {}
    for key in obj:
        if key in keys:
            new_obj[key] = obj[key]
    return new_obj

# %%
objects_rdd = sc.parallelize(objects)

# %%
objects_rdd = objects_rdd.map(lambda x: getFields(x))

# %%
objects_rdd.collect()
# Out:
# 24/12/19 20:27:23 WARN TaskSetManager: Stage 1 contains a task of very large size (3502 KiB). The maximum recommended task size is 1000 KiB.
# [{'objectID': 14,
#   'isHighlight': False,
#   'accessionYear': '1979',
#   'department': 'The American Wing',
#   'objectName': 'Coin',
#   'culture': '',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1907,
#   'isTimelineWork': False},
#  {'objectID': 78,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Andiron',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1700,
#   'isTimelineWork': False},
#  {'objectID': 108,
#   'isHighlight': False,
#   'accessionYear': '1989',
#   'department': 'The American Wing',
#   'objectName': 'Andiron',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1814,
#   'isTimelineWork': False},
#  {'objectID': 227,
#   'isHighlight': False,
#   'accessionYear': '1968',
#   'department': 'The American Wing',
#   'objectName': 'Armchair',
#   'culture': 'American',
#   'artistNationality': 'French',
#   'artistGender': '',
#   'objectEndDate': 1860,
#   'isTimelineWork': False},
#  {'objectID': 292,
#   'isHighlight': False,
#   'accessionYear': '1968',
#   'department': 'The American Wing',
#   'objectName': 'Furniture hardware',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 366,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Basket',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1890,
#   'isTimelineWork': False},
#  {'objectID': 416,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Beaker',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1711,
#   'isTimelineWork': True},
#  {'objectID': 423,
#   'isHighlight': False,
#   'accessionYear': '1901',
#   'department': 'The American Wing',
#   'objectName': 'Beaker',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 2830,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Cup',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 540,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Bitters bottle',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 652,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Bottle fragment',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 653,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Bottle fragment',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 672,
#   'isHighlight': False,
#   'accessionYear': '1911',
#   'department': 'The American Wing',
#   'objectName': 'Bowl',
#   'culture': 'Mexican',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 779,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Bowl',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1880,
#   'isTimelineWork': False},
#  {'objectID': 856,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Bowl',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 867,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Bowl',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 895,
#   'isHighlight': False,
#   'accessionYear': '1917',
#   'department': 'The American Wing',
#   'objectName': 'Cup',
#   'culture': 'Mexican',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1845,
#   'isTimelineWork': False},
#  {'objectID': 903,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Medallion',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1883,
#   'isTimelineWork': False},
#  {'objectID': 906,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Box',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 3265,
#   'isHighlight': False,
#   'accessionYear': '1951',
#   'department': 'The American Wing',
#   'objectName': 'Dish',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 992,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Bread plate',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 1017,
#   'isHighlight': False,
#   'accessionYear': '1934',
#   'department': 'The American Wing',
#   'objectName': 'Bride box',
#   'culture': 'European',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1787,
#   'isTimelineWork': False},
#  {'objectID': 1054,
#   'isHighlight': False,
#   'accessionYear': '1934',
#   'department': 'The American Wing',
#   'objectName': 'Butter mold',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 1146,
#   'isHighlight': False,
#   'accessionYear': '1967',
#   'department': 'The American Wing',
#   'objectName': 'Candelabrum',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 1235,
#   'isHighlight': False,
#   'accessionYear': '1924',
#   'department': 'The American Wing',
#   'objectName': 'Candlestick',
#   'culture': 'British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 1326,
#   'isHighlight': False,
#   'accessionYear': '1962',
#   'department': 'The American Wing',
#   'objectName': 'Candlestick',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1860,
#   'isTimelineWork': False},
#  {'objectID': 1373,
#   'isHighlight': False,
#   'accessionYear': '1930',
#   'department': 'The American Wing',
#   'objectName': 'Candlestick and shade',
#   'culture': 'British, probably',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 3796,
#   'isHighlight': False,
#   'accessionYear': '1942',
#   'department': 'The American Wing',
#   'objectName': 'Footstool',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1820,
#   'isTimelineWork': False},
#  {'objectID': 1500,
#   'isHighlight': False,
#   'accessionYear': '1969',
#   'department': 'The American Wing',
#   'objectName': 'Celery vase',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1825,
#   'isTimelineWork': False},
#  {'objectID': 1845,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Side Chair',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 1906,
#   'isHighlight': False,
#   'accessionYear': '1965',
#   'department': 'The American Wing',
#   'objectName': 'Side Chair',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1820,
#   'isTimelineWork': False},
#  {'objectID': 1919,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1889,
#   'isTimelineWork': False},
#  {'objectID': 2066,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Churn',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 2105,
#   'isHighlight': False,
#   'accessionYear': '1947',
#   'department': 'The American Wing',
#   'objectName': 'Figure',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 2126,
#   'isHighlight': False,
#   'accessionYear': '1987',
#   'department': 'The American Wing',
#   'objectName': 'Urn',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1845,
#   'isTimelineWork': False},
#  {'objectID': 4924,
#   'isHighlight': False,
#   'accessionYear': '1934',
#   'department': 'The American Wing',
#   'objectName': 'Mangle board',
#   'culture': 'European',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 2617,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Cream pot',
#   'culture': 'British, probably',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1885,
#   'isTimelineWork': False},
#  {'objectID': 2620,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Cream pot',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 2636,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Cream pitcher',
#   'culture': 'French, possibly',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1780,
#   'isTimelineWork': False},
#  {'objectID': 2724,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Cream pot',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1818,
#   'isTimelineWork': False},
#  {'objectID': 2753,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Cruet',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1886,
#   'isTimelineWork': False},
#  {'objectID': 2770,
#   'isHighlight': False,
#   'accessionYear': '1935',
#   'department': 'The American Wing',
#   'objectName': 'Cup',
#   'culture': 'Chinese',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 5435,
#   'isHighlight': False,
#   'accessionYear': '1982',
#   'department': 'The American Wing',
#   'objectName': 'Whale oil lamp',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 5463,
#   'isHighlight': False,
#   'accessionYear': '1932',
#   'department': 'The American Wing',
#   'objectName': 'Whale oil lamp',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 3438,
#   'isHighlight': False,
#   'accessionYear': '1981',
#   'department': 'The American Wing',
#   'objectName': 'Dressing Table',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1760,
#   'isTimelineWork': False},
#  {'objectID': 3591,
#   'isHighlight': False,
#   'accessionYear': '1941',
#   'department': 'The American Wing',
#   'objectName': 'Fender',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1815,
#   'isTimelineWork': False},
#  {'objectID': 3733,
#   'isHighlight': False,
#   'accessionYear': '1945',
#   'department': 'The American Wing',
#   'objectName': 'Flask',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1824,
#   'isTimelineWork': False},
#  {'objectID': 5914,
#   'isHighlight': False,
#   'accessionYear': '1986',
#   'department': 'The American Wing',
#   'objectName': 'Plaque',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1895,
#   'isTimelineWork': False},
#  {'objectID': 5953,
#   'isHighlight': False,
#   'accessionYear': '1911',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'Mexican',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 5984,
#   'isHighlight': False,
#   'accessionYear': '1917',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1825,
#   'isTimelineWork': False},
#  {'objectID': 6001,
#   'isHighlight': False,
#   'accessionYear': '1934',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1808,
#   'isTimelineWork': False},
#  {'objectID': 3811,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Frame',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1770,
#   'isTimelineWork': False},
#  {'objectID': 3849,
#   'isHighlight': False,
#   'accessionYear': '1978',
#   'department': 'The American Wing',
#   'objectName': 'Fruit bowl',
#   'culture': 'American, Japanese',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1922,
#   'isTimelineWork': False},
#  {'objectID': 3856,
#   'isHighlight': False,
#   'accessionYear': '1985',
#   'department': 'The American Wing',
#   'objectName': 'Solid Casting Pattern',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1878,
#   'isTimelineWork': False},
#  {'objectID': 3891,
#   'isHighlight': False,
#   'accessionYear': '',
#   'department': 'The American Wing',
#   'objectName': 'Gas lighting fixture',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1895,
#   'isTimelineWork': False},
#  {'objectID': 3895,
#   'isHighlight': False,
#   'accessionYear': '',
#   'department': 'The American Wing',
#   'objectName': 'Gas lighting fixture',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1895,
#   'isTimelineWork': False},
#  {'objectID': 4009,
#   'isHighlight': False,
#   'accessionYear': '1913',
#   'department': 'The American Wing',
#   'objectName': 'Fragment',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1774,
#   'isTimelineWork': False},
#  {'objectID': 4219,
#   'isHighlight': False,
#   'accessionYear': '1913',
#   'department': 'The American Wing',
#   'objectName': 'Furniture hardware',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 4287,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'High chest of drawers',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1740,
#   'isTimelineWork': False},
#  {'objectID': 4307,
#   'isHighlight': False,
#   'accessionYear': '1949',
#   'department': 'The American Wing',
#   'objectName': 'Hinge',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1730,
#   'isTimelineWork': False},
#  {'objectID': 2929,
#   'isHighlight': False,
#   'accessionYear': '1945',
#   'department': 'The American Wing',
#   'objectName': 'Cup plate',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1860,
#   'isTimelineWork': False},
#  {'objectID': 2982,
#   'isHighlight': False,
#   'accessionYear': '1963',
#   'department': 'The American Wing',
#   'objectName': 'Curtain knob',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1875,
#   'isTimelineWork': False},
#  {'objectID': 3029,
#   'isHighlight': False,
#   'accessionYear': '1961',
#   'department': 'The American Wing',
#   'objectName': 'Curtain tieback',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1895,
#   'isTimelineWork': False},
#  {'objectID': 3092,
#   'isHighlight': False,
#   'accessionYear': '1959',
#   'department': 'The American Wing',
#   'objectName': 'Decanter',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 4547,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Joint stool',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1725,
#   'isTimelineWork': False},
#  {'objectID': 4614,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Buckle',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1775,
#   'isTimelineWork': False},
#  {'objectID': 4686,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Lamp',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 4716,
#   'isHighlight': False,
#   'accessionYear': '1989',
#   'department': 'The American Wing',
#   'objectName': 'Lamp',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1915,
#   'isTimelineWork': True},
#  {'objectID': 4723,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Chimney lamp',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 4801,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Lock and key',
#   'culture': 'American or British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 7332,
#   'isHighlight': False,
#   'accessionYear': '1980',
#   'department': 'The American Wing',
#   'objectName': 'Scent bottle',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1860,
#   'isTimelineWork': False},
#  {'objectID': 7356,
#   'isHighlight': False,
#   'accessionYear': '1942',
#   'department': 'The American Wing',
#   'objectName': 'Sconce',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1815,
#   'isTimelineWork': False},
#  {'objectID': 7426,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Sherbet dish',
#   'culture': 'British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1885,
#   'isTimelineWork': False},
#  {'objectID': 7453,
#   'isHighlight': False,
#   'accessionYear': '1924',
#   'department': 'The American Wing',
#   'objectName': 'Shoe buckle',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 6129,
#   'isHighlight': False,
#   'accessionYear': '1988',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1891,
#   'isTimelineWork': False},
#  {'objectID': 6131,
#   'isHighlight': False,
#   'accessionYear': '1914',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'British (American market)',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1883,
#   'isTimelineWork': False},
#  {'objectID': 6149,
#   'isHighlight': False,
#   'accessionYear': '1914',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'British (American market)',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1838,
#   'isTimelineWork': False},
#  {'objectID': 6155,
#   'isHighlight': False,
#   'accessionYear': '1986',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': 'Female',
#   'objectEndDate': 1903,
#   'isTimelineWork': False},
#  {'objectID': 6170,
#   'isHighlight': False,
#   'accessionYear': '1963',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1896,
#   'isTimelineWork': False},
#  {'objectID': 6285,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 6360,
#   'isHighlight': False,
#   'accessionYear': '',
#   'department': 'The American Wing',
#   'objectName': 'Plate',
#   'culture': 'French',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 7964,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Sugar bowl',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1887,
#   'isTimelineWork': False},
#  {'objectID': 5018,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Medal',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1841,
#   'isTimelineWork': False},
#  {'objectID': 5033,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Medallion',
#   'culture': '',
#   'artistNationality': 'French',
#   'artistGender': '',
#   'objectEndDate': 1786,
#   'isTimelineWork': False},
#  {'objectID': 5087,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Medal',
#   'culture': '',
#   'artistNationality': 'French',
#   'artistGender': '',
#   'objectEndDate': 1777,
#   'isTimelineWork': False},
#  {'objectID': 5141,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Plaque',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 5246,
#   'isHighlight': False,
#   'accessionYear': '1968',
#   'department': 'The American Wing',
#   'objectName': 'Furniture hardware',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 5290,
#   'isHighlight': False,
#   'accessionYear': '1915',
#   'department': 'The American Wing',
#   'objectName': 'Mug',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 5315,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Mug',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1736,
#   'isTimelineWork': False},
#  {'objectID': 5316,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Mug',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1890,
#   'isTimelineWork': False},
#  {'objectID': 5320,
#   'isHighlight': False,
#   'accessionYear': '1941',
#   'department': 'The American Wing',
#   'objectName': 'Mug',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 5396,
#   'isHighlight': False,
#   'accessionYear': '1971',
#   'department': 'The American Wing',
#   'objectName': 'Music stand',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 5408,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Niddy noddy',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 8251,
#   'isHighlight': False,
#   'accessionYear': '1952',
#   'department': 'The American Wing',
#   'objectName': 'Taperstick',
#   'culture': 'British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1770,
#   'isTimelineWork': False},
#  {'objectID': 8262,
#   'isHighlight': False,
#   'accessionYear': '1959',
#   'department': 'The American Wing',
#   'objectName': 'Tea Caddy',
#   'culture': 'British',
#   'artistNationality': 'Norwegian',
#   'artistGender': '',
#   'objectEndDate': 1763,
#   'isTimelineWork': False},
#  {'objectID': 8278,
#   'isHighlight': False,
#   'accessionYear': '1939',
#   'department': 'The American Wing',
#   'objectName': 'Tea table',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 5630,
#   'isHighlight': True,
#   'accessionYear': '1976',
#   'department': 'The American Wing',
#   'objectName': 'Pier table',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1815,
#   'isTimelineWork': False},
#  {'objectID': 5743,
#   'isHighlight': False,
#   'accessionYear': '1947',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 5825,
#   'isHighlight': False,
#   'accessionYear': '1984',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1861,
#   'isTimelineWork': False},
#  {'objectID': 5838,
#   'isHighlight': False,
#   'accessionYear': '1908',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1863,
#   'isTimelineWork': False},
#  {'objectID': 5853,
#   'isHighlight': False,
#   'accessionYear': '1970',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1838,
#   'isTimelineWork': False},
#  {'objectID': 5878,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Cream pot',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1810,
#   'isTimelineWork': False},
#  {'objectID': 5880,
#   'isHighlight': False,
#   'accessionYear': '1982',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'British (American market)',
#   'artistNationality': 'British',
#   'artistGender': '',
#   'objectEndDate': 1890,
#   'isTimelineWork': False},
#  {'objectID': 8534,
#   'isHighlight': False,
#   'accessionYear': '1977',
#   'department': 'The American Wing',
#   'objectName': 'Tile',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1884,
#   'isTimelineWork': False},
#  {'objectID': 8706,
#   'isHighlight': False,
#   'accessionYear': '1883',
#   'department': 'The American Wing',
#   'objectName': 'Token',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1876,
#   'isTimelineWork': False},
#  {'objectID': 6905,
#   'isHighlight': False,
#   'accessionYear': '1967',
#   'department': 'The American Wing',
#   'objectName': 'Roundabout armchair',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 6972,
#   'isHighlight': False,
#   'accessionYear': '1913',
#   'department': 'The American Wing',
#   'objectName': 'Saltcellar',
#   'culture': 'American or British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1825,
#   'isTimelineWork': False},
#  {'objectID': 7043,
#   'isHighlight': False,
#   'accessionYear': '1951',
#   'department': 'The American Wing',
#   'objectName': 'Salt',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 7073,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Saltcellar',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1835,
#   'isTimelineWork': False},
#  {'objectID': 7109,
#   'isHighlight': False,
#   'accessionYear': '1911',
#   'department': 'The American Wing',
#   'objectName': 'Sand shaker',
#   'culture': 'Mexican',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 7208,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'The American Wing',
#   'objectName': 'Sauceboat',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1790,
#   'isTimelineWork': False},
#  {'objectID': 7229,
#   'isHighlight': False,
#   'accessionYear': '1935',
#   'department': 'The American Wing',
#   'objectName': 'Saucer',
#   'culture': 'Chinese',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 7259,
#   'isHighlight': False,
#   'accessionYear': '1960',
#   'department': 'The American Wing',
#   'objectName': 'Saucer',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1866,
#   'isTimelineWork': False},
#  {'objectID': 9740,
#   'isHighlight': False,
#   'accessionYear': '1894',
#   'department': 'The American Wing',
#   'objectName': 'Waste Bowl',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1825,
#   'isTimelineWork': False},
#  {'objectID': 9781,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Water pitcher',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1888,
#   'isTimelineWork': False},
#  {'objectID': 9783,
#   'isHighlight': False,
#   'accessionYear': '1969',
#   'department': 'The American Wing',
#   'objectName': 'Pitcher',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1846,
#   'isTimelineWork': False},
#  {'objectID': 6603,
#   'isHighlight': False,
#   'accessionYear': '1942',
#   'department': 'The American Wing',
#   'objectName': 'Pocket flask',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 6694,
#   'isHighlight': False,
#   'accessionYear': '1941',
#   'department': 'The American Wing',
#   'objectName': 'Porringer',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1809,
#   'isTimelineWork': False},
#  {'objectID': 6788,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Miniature',
#   'culture': '',
#   'artistNationality': 'German',
#   'artistGender': '',
#   'objectEndDate': 1812,
#   'isTimelineWork': False},
#  {'objectID': 6810,
#   'isHighlight': False,
#   'accessionYear': '1911',
#   'department': 'The American Wing',
#   'objectName': 'Embroidery punch',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 6833,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Quart decanter',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 9164,
#   'isHighlight': False,
#   'accessionYear': '1952',
#   'department': 'The American Wing',
#   'objectName': 'Bottle',
#   'culture': 'British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1775,
#   'isTimelineWork': False},
#  {'objectID': 9189,
#   'isHighlight': False,
#   'accessionYear': '1983',
#   'department': 'The American Wing',
#   'objectName': 'Pedestal',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1875,
#   'isTimelineWork': False},
#  {'objectID': 9211,
#   'isHighlight': False,
#   'accessionYear': '1930',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1875,
#   'isTimelineWork': False},
#  {'objectID': 9214,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 9353,
#   'isHighlight': False,
#   'accessionYear': '1991',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1890,
#   'isTimelineWork': True},
#  {'objectID': 7578,
#   'isHighlight': False,
#   'accessionYear': '1939',
#   'department': 'The American Wing',
#   'objectName': 'Sofa',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1820,
#   'isTimelineWork': False},
#  {'objectID': 7594,
#   'isHighlight': False,
#   'accessionYear': '1959',
#   'department': 'The American Wing',
#   'objectName': 'Sofa',
#   'culture': 'American',
#   'artistNationality': 'American, born Scotland',
#   'artistGender': '',
#   'objectEndDate': 1820,
#   'isTimelineWork': False},
#  {'objectID': 7627,
#   'isHighlight': False,
#   'accessionYear': '1960',
#   'department': 'The American Wing',
#   'objectName': 'Soup dish',
#   'culture': 'Chinese, for American market',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1866,
#   'isTimelineWork': False},
#  {'objectID': 10277,
#   'isHighlight': False,
#   'accessionYear': '1899',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1879,
#   'isTimelineWork': False},
#  {'objectID': 10308,
#   'isHighlight': False,
#   'accessionYear': '1899',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1876,
#   'isTimelineWork': False},
#  {'objectID': 10368,
#   'isHighlight': False,
#   'accessionYear': '1926',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1851,
#   'isTimelineWork': False},
#  {'objectID': 10382,
#   'isHighlight': False,
#   'accessionYear': '1979',
#   'department': 'The American Wing',
#   'objectName': 'Sketchbook',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1893,
#   'isTimelineWork': False},
#  {'objectID': 10483,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Painting, miniature',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 10505,
#   'isHighlight': False,
#   'accessionYear': '1978',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1885,
#   'isTimelineWork': False},
#  {'objectID': 7974,
#   'isHighlight': False,
#   'accessionYear': '1982',
#   'department': 'The American Wing',
#   'objectName': 'Sugar bowl',
#   'culture': 'British (American market)',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1839,
#   'isTimelineWork': False},
#  {'objectID': 8049,
#   'isHighlight': False,
#   'accessionYear': '1947',
#   'department': 'The American Wing',
#   'objectName': 'Syrup jug',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1858,
#   'isTimelineWork': False},
#  {'objectID': 8125,
#   'isHighlight': False,
#   'accessionYear': '1924',
#   'department': 'The American Wing',
#   'objectName': 'Spoon',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1780,
#   'isTimelineWork': False},
#  {'objectID': 8166,
#   'isHighlight': False,
#   'accessionYear': '1942',
#   'department': 'The American Wing',
#   'objectName': 'Tall clock',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1825,
#   'isTimelineWork': False},
#  {'objectID': 10764,
#   'isHighlight': False,
#   'accessionYear': '1937',
#   'department': 'The American Wing',
#   'objectName': 'Painting, miniature',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1814,
#   'isTimelineWork': False},
#  {'objectID': 10783,
#   'isHighlight': False,
#   'accessionYear': '1913',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1829,
#   'isTimelineWork': False},
#  {'objectID': 10810,
#   'isHighlight': False,
#   'accessionYear': '1967',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1883,
#   'isTimelineWork': False},
#  {'objectID': 10829,
#   'isHighlight': False,
#   'accessionYear': '1925',
#   'department': 'The American Wing',
#   'objectName': 'Watercolor',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1877,
#   'isTimelineWork': False},
#  {'objectID': 10911,
#   'isHighlight': False,
#   'accessionYear': '1919',
#   'department': 'The American Wing',
#   'objectName': 'Sculpture',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1919,
#   'isTimelineWork': True},
#  {'objectID': 10929,
#   'isHighlight': False,
#   'accessionYear': '1914',
#   'department': 'The American Wing',
#   'objectName': 'Painting, miniature',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1813,
#   'isTimelineWork': True},
#  {'objectID': 10964,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Watercolor',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1950,
#   'isTimelineWork': False},
#  {'objectID': 8781,
#   'isHighlight': False,
#   'accessionYear': '1951',
#   'department': 'The American Wing',
#   'objectName': 'Tray',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1850,
#   'isTimelineWork': False},
#  {'objectID': 8973,
#   'isHighlight': False,
#   'accessionYear': '1978',
#   'department': 'The American Wing',
#   'objectName': 'Trivet',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 9056,
#   'isHighlight': False,
#   'accessionYear': '1981',
#   'department': 'The American Wing',
#   'objectName': 'Tumbler',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1827,
#   'isTimelineWork': False},
#  {'objectID': 9066,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Tumbler',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 9139,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Tumbler',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1896,
#   'isTimelineWork': False},
#  {'objectID': 11670,
#   'isHighlight': False,
#   'accessionYear': '1926',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1850,
#   'isTimelineWork': False},
#  {'objectID': 11674,
#   'isHighlight': False,
#   'accessionYear': '1925',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1838,
#   'isTimelineWork': False},
#  {'objectID': 11695,
#   'isHighlight': False,
#   'accessionYear': '1976',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': 'Female',
#   'objectEndDate': 1920,
#   'isTimelineWork': False},
#  {'objectID': 8298,
#   'isHighlight': False,
#   'accessionYear': '1969',
#   'department': 'The American Wing',
#   'objectName': 'Teacup and saucer',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1876,
#   'isTimelineWork': False},
#  {'objectID': 8440,
#   'isHighlight': False,
#   'accessionYear': '1933',
#   'department': 'The American Wing',
#   'objectName': 'Spoon',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 8475,
#   'isHighlight': False,
#   'accessionYear': '1923',
#   'department': 'The American Wing',
#   'objectName': 'Spoon',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 8491,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Miniature',
#   'culture': '',
#   'artistNationality': 'German',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 8497,
#   'isHighlight': False,
#   'accessionYear': '1943',
#   'department': 'The American Wing',
#   'objectName': 'Tile',
#   'culture': 'British',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1776,
#   'isTimelineWork': False},
#  {'objectID': 11220,
#   'isHighlight': False,
#   'accessionYear': '1926',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1826,
#   'isTimelineWork': False},
#  {'objectID': 11231,
#   'isHighlight': False,
#   'accessionYear': '1967',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1889,
#   'isTimelineWork': True},
#  {'objectID': 11285,
#   'isHighlight': False,
#   'accessionYear': '1988',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1929,
#   'isTimelineWork': False},
#  {'objectID': 11470,
#   'isHighlight': False,
#   'accessionYear': '1912',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1910,
#   'isTimelineWork': False},
#  {'objectID': 11473,
#   'isHighlight': False,
#   'accessionYear': '1925',
#   'department': 'The American Wing',
#   'objectName': 'Painting, miniature',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 9907,
#   'isHighlight': False,
#   'accessionYear': '1969',
#   'department': 'The American Wing',
#   'objectName': 'Wineglass',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1830,
#   'isTimelineWork': False},
#  {'objectID': 9926,
#   'isHighlight': False,
#   'accessionYear': '1926',
#   'department': 'The American Wing',
#   'objectName': 'Wine glass',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1840,
#   'isTimelineWork': False},
#  {'objectID': 9975,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Wine glass',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1870,
#   'isTimelineWork': False},
#  {'objectID': 10007,
#   'isHighlight': False,
#   'accessionYear': '1980',
#   'department': 'The American Wing',
#   'objectName': 'Work table',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1815,
#   'isTimelineWork': False},
#  {'objectID': 10012,
#   'isHighlight': False,
#   'accessionYear': '1966',
#   'department': 'The American Wing',
#   'objectName': 'Work table',
#   'culture': 'American',
#   'artistNationality': 'American, born Scotland',
#   'artistGender': '',
#   'objectEndDate': 1820,
#   'isTimelineWork': False},
#  {'objectID': 10105,
#   'isHighlight': False,
#   'accessionYear': '1896',
#   'department': 'The American Wing',
#   'objectName': 'Sculpture',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1894,
#   'isTimelineWork': False},
#  {'objectID': 10107,
#   'isHighlight': False,
#   'accessionYear': '1891',
#   'department': 'The American Wing',
#   'objectName': 'Sculpture',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1888,
#   'isTimelineWork': True},
#  {'objectID': 12997,
#   'isHighlight': False,
#   'accessionYear': '1927',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': '',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1765,
#   'isTimelineWork': False},
#  {'objectID': 13057,
#   'isHighlight': False,
#   'accessionYear': '1962',
#   'department': 'The American Wing',
#   'objectName': 'Painting',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1732,
#   'isTimelineWork': False},
#  {'objectID': 9401,
#   'isHighlight': False,
#   'accessionYear': '1896',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1896,
#   'isTimelineWork': False},
#  {'objectID': 9510,
#   'isHighlight': False,
#   'accessionYear': '1942',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'French',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1824,
#   'isTimelineWork': False},
#  {'objectID': 9521,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'American',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1860,
#   'isTimelineWork': False},
#  {'objectID': 9569,
#   'isHighlight': False,
#   'accessionYear': '1926',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'Dutch',
#   'artistNationality': 'Dutch',
#   'artistGender': '',
#   'objectEndDate': 1775,
#   'isTimelineWork': False},
#  {'objectID': 9584,
#   'isHighlight': False,
#   'accessionYear': '1930',
#   'department': 'The American Wing',
#   'objectName': 'Vase',
#   'culture': 'Chinese',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1800,
#   'isTimelineWork': False},
#  {'objectID': 12076,
#   'isHighlight': False,
#   'accessionYear': '1950',
#   'department': 'The American Wing',
#   'objectName': 'Drawing',
#   'culture': 'American',
#   'artistNationality': 'American',
#   'artistGender': '',
#   'objectEndDate': 1910,
# ...
#   'artistGender': '',
#   'objectEndDate': 1792,
#   'isTimelineWork': False},
#  {'objectID': 55360,
#   'isHighlight': False,
#   'accessionYear': '1922',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1780,
#   'isTimelineWork': False},
#  {'objectID': 53005,
#   'isHighlight': False,
#   'accessionYear': '2015',
#   'department': 'Asian Art',
#   'objectName': 'Serving dish',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1633,
#   'isTimelineWork': False},
#  {'objectID': 56035,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1784,
#   'isTimelineWork': False},
#  {'objectID': 56084,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1819,
#   'isTimelineWork': False},
#  {'objectID': 56091,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 56097,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1867,
#   'isTimelineWork': False},
#  {'objectID': 56203,
#   'isHighlight': False,
#   'accessionYear': '1902',
#   'department': 'Asian Art',
#   'objectName': 'Wine cup',
#   'culture': 'India',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 56244,
#   'isHighlight': False,
#   'accessionYear': '1902',
#   'department': 'Asian Art',
#   'objectName': 'Armlet',
#   'culture': 'India',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 56481,
#   'isHighlight': False,
#   'accessionYear': '2001',
#   'department': 'Asian Art',
#   'objectName': 'Drum',
#   'culture': 'Thailand (Chuchong District)',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 300,
#   'isTimelineWork': False},
#  {'objectID': 56490,
#   'isHighlight': False,
#   'accessionYear': '1946',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1749,
#   'isTimelineWork': False},
#  {'objectID': 56547,
#   'isHighlight': False,
#   'accessionYear': '1891',
#   'department': 'Asian Art',
#   'objectName': 'Basket',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1900,
#   'isTimelineWork': False},
#  {'objectID': 56582,
#   'isHighlight': False,
#   'accessionYear': '2001',
#   'department': 'Asian Art',
#   'objectName': 'Bell',
#   'culture': 'Vietnam (North)',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 300,
#   'isTimelineWork': False},
#  {'objectID': 56600,
#   'isHighlight': False,
#   'accessionYear': '1949',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1761,
#   'isTimelineWork': False},
#  {'objectID': 56605,
#   'isHighlight': False,
#   'accessionYear': '1949',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1757,
#   'isTimelineWork': False},
#  {'objectID': 56606,
#   'isHighlight': False,
#   'accessionYear': '1949',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1768,
#   'isTimelineWork': False},
#  {'objectID': 55723,
#   'isHighlight': False,
#   'accessionYear': '1975',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1865,
#   'isTimelineWork': False},
#  {'objectID': 55728,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1852,
#   'isTimelineWork': False},
#  {'objectID': 55746,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Prints',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1792,
#   'isTimelineWork': False},
#  {'objectID': 55755,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Woodblock print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1694,
#   'isTimelineWork': False},
#  {'objectID': 55853,
#   'isHighlight': False,
#   'accessionYear': '1979',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1895,
#   'isTimelineWork': False},
#  {'objectID': 58643,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Inrō',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 54830,
#   'isHighlight': False,
#   'accessionYear': '1914',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1801,
#   'isTimelineWork': False},
#  {'objectID': 54843,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 57201,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Album leaf',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1868,
#   'isTimelineWork': False},
#  {'objectID': 57356,
#   'isHighlight': False,
#   'accessionYear': '1915',
#   'department': 'Asian Art',
#   'objectName': 'Jar',
#   'culture': 'Korea',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1933,
#   'isTimelineWork': False},
#  {'objectID': 57373,
#   'isHighlight': False,
#   'accessionYear': '1917',
#   'department': 'Asian Art',
#   'objectName': 'Statuette',
#   'culture': 'Korea',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 699,
#   'isTimelineWork': False},
#  {'objectID': 57448,
#   'isHighlight': False,
#   'accessionYear': '1917',
#   'department': 'Asian Art',
#   'objectName': 'Ornament',
#   'culture': 'Korea',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1392,
#   'isTimelineWork': False},
#  {'objectID': 57549,
#   'isHighlight': False,
#   'accessionYear': '1918',
#   'department': 'Asian Art',
#   'objectName': 'Illustrated book',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1813,
#   'isTimelineWork': False},
#  {'objectID': 57609,
#   'isHighlight': False,
#   'accessionYear': '1881',
#   'department': 'Asian Art',
#   'objectName': 'Box',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 54375,
#   'isHighlight': False,
#   'accessionYear': '1921',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1828,
#   'isTimelineWork': False},
#  {'objectID': 54394,
#   'isHighlight': False,
#   'accessionYear': '1923',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 54400,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1850,
#   'isTimelineWork': False},
#  {'objectID': 56700,
#   'isHighlight': False,
#   'accessionYear': '1949',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1858,
#   'isTimelineWork': False},
#  {'objectID': 56713,
#   'isHighlight': False,
#   'accessionYear': '1951',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1806,
#   'isTimelineWork': False},
#  {'objectID': 56714,
#   'isHighlight': False,
#   'accessionYear': '1952',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1806,
#   'isTimelineWork': False},
#  {'objectID': 56769,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1747,
#   'isTimelineWork': False},
#  {'objectID': 56823,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1733,
#   'isTimelineWork': False},
#  {'objectID': 56849,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1795,
#   'isTimelineWork': False},
#  {'objectID': 56851,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1784,
#   'isTimelineWork': False},
#  {'objectID': 56918,
#   'isHighlight': False,
#   'accessionYear': '1936',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1843,
#   'isTimelineWork': False},
#  {'objectID': 57020,
#   'isHighlight': False,
#   'accessionYear': '1939',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1864,
#   'isTimelineWork': False},
#  {'objectID': 55370,
#   'isHighlight': False,
#   'accessionYear': '1959',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1916,
#   'isTimelineWork': False},
#  {'objectID': 55391,
#   'isHighlight': False,
#   'accessionYear': '1959',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1916,
#   'isTimelineWork': False},
#  {'objectID': 57864,
#   'isHighlight': False,
#   'accessionYear': '1960',
#   'department': 'Asian Art',
#   'objectName': 'Illustrated book',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1931,
#   'isTimelineWork': False},
#  {'objectID': 58038,
#   'isHighlight': False,
#   'accessionYear': '1914',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1866,
#   'isTimelineWork': False},
#  {'objectID': 58207,
#   'isHighlight': False,
#   'accessionYear': '',
#   'department': 'Asian Art',
#   'objectName': 'Print',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1854,
#   'isTimelineWork': False},
#  {'objectID': 58242,
#   'isHighlight': False,
#   'accessionYear': '1929',
#   'department': 'Asian Art',
#   'objectName': 'Box',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1699,
#   'isTimelineWork': False},
#  {'objectID': 58334,
#   'isHighlight': False,
#   'accessionYear': '1958',
#   'department': 'Asian Art',
#   'objectName': 'Writing box',
#   'culture': 'Japan',
#   'artistNationality': 'Japanese',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 58341,
#   'isHighlight': False,
#   'accessionYear': '1967',
#   'department': 'Asian Art',
#   'objectName': "Traveller's shrine",
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 58371,
#   'isHighlight': False,
#   'accessionYear': '1879',
#   'department': 'Asian Art',
#   'objectName': 'Inrō with netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 58377,
#   'isHighlight': False,
#   'accessionYear': '1881',
#   'department': 'Asian Art',
#   'objectName': 'Inrō',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 58390,
#   'isHighlight': False,
#   'accessionYear': '1881',
#   'department': 'Asian Art',
#   'objectName': 'Inrō',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59149,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59156,
#   'isHighlight': False,
#   'accessionYear': '1881',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59173,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 19,
#   'isTimelineWork': False},
#  {'objectID': 59174,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59177,
#   'isHighlight': False,
#   'accessionYear': '1881',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59249,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59267,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 59288,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1799,
#   'isTimelineWork': False},
#  {'objectID': 59300,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  {'objectID': 59304,
#   'isHighlight': False,
#   'accessionYear': '1910',
#   'department': 'Asian Art',
#   'objectName': 'Netsuke',
#   'culture': 'Japan',
#   'artistNationality': '',
#   'artistGender': '',
#   'objectEndDate': 1899,
#   'isTimelineWork': False},
#  ...]

# %%
df = objects_rdd.toDF()
# Out:
# 24/12/19 20:27:25 WARN TaskSetManager: Stage 2 contains a task of very large size (3502 KiB). The maximum recommended task size is 1000 KiB.

# %%
import os
path = os.getcwd() + "/extractedDataset"
df.repartition(1).write.csv(path, mode='overwrite', header=True)

# %%
spark.stop()
